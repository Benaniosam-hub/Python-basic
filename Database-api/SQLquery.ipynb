# %% [markdown]
# 26.Have you used SQL? Write a query to find all employees with a salary greater than 50,000.

# %% [markdown]
# Yes, I have used mySQLite and postgreySQL to connect with my python program to do CRUD operation and to find all employees with a salary greater than 50,000 is,
#
# SELECT * FROM employees WHERE salary >= 50000;
