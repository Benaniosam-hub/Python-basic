# %% [markdown]
# 27.⁠ ⁠What is a REST API?
#
# Representational State Transfer Application Programming Interface which helps to communicate safetly like a bridge between two software or application the

# %% [markdown]
# GET: Ask the server to read or fetch data.
# POST: Tell the server to create a new piece of data.
# PUT: Ask the server to update existing data.
# DELETE: Request the server to remove data
