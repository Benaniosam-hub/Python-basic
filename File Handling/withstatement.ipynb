# %% [markdown]
# 19.⁠ ⁠Why is the with statement used when opening files?

# %% [markdown]
# By using with statement while running the code, the file will close automatically even it executes the output or not. This helps to prevent from unwanted usage of memory after the usecase.

# %%
with open("temp.txt","r") as file:
    print(file.read())
