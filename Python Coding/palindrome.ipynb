# %% [markdown]
# 22.⁠ ⁠Write a function to check whether a string is a palindrome.

# %%
def palindrome(name):
    name=str(name).lower()
    reverse_name=name[::-1]
    
    if rename != name:
        print("its not a palindrome")
    else:
        print("its a palindrome")
palindrome("radar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7     else:
#       8         print("its a palindrome")
# ----> 9 palindrome("radar")
#
# Cell In[4], line 5, in palindrome(name)
#       2 name=str(name).lower()
#       3 reverse_name=name[::-1]
# ----> 5 if new_name != name:
#       6     print("its not a palindrome")
#       7 else:
#
# NameError: name 'new_name' is not defined
