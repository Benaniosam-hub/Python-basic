# %% [markdown]
# 11.⁠ ⁠What is inheritance?

# %% [markdown]
# Inheritance is one of the core concept in OOP (Object Oriented Programming) that allows a new class (child or derived) to adapt all the attributes and methods from an existing class (parent or base class).

# %% [markdown]
# There are types of inheritance:
# 1.Single inheritance
# 2.Multiple inheritance
# 3.Multilevel inheritance
# 4.Hierarchical inheritance
# 5.hybrid inheritance

# %%
class Animal:
    def eat(self):
        print("Animal eats")
class dog(Animal):
    def bark(self):
        print("Dog barks")

my_dog=dog()

my_dog.eat()
my_dog.bark()
# Out:
# Animal eats
# Dog barks
