# %% [markdown]
# 18.⁠ ⁠How do you write data to a file?

# %%
with open("/Users/sam/my_repositor/Python-basic/.ipynb_checkpoints/geeks.txt", "a") as file:
    file.write("WARNING ISHOWSPEED\n")
    file.write("IS BACK AGAIN\n")

with open("/Users/sam/my_repositor/Python-basic/.ipynb_checkpoints/geeks.txt", "r") as file:
    print(file.read())

# %% [markdown]
# to write a file use "w" or "a" for append where it adds the content at the end, inside the open() statement
# if we use the write it rewrites the content i
