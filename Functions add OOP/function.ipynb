# %%
 8.⁠ ⁠What is a function in Python?

# %%
# to run a specific task by calling a function name, 
# it gonna run that specific code written inside the function.

def codeForNow():
    list=[x for x in range(5)]
    return list
new_code = codeForNow()
print(new_code)
