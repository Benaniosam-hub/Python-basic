# %% [markdown]
# 14.⁠ ⁠What is an exception?

# %% [markdown]
# While running a code a runtime error occurs is known for exception

# %%
try:
    age = int(input("Enter the age:"))
    days=age*365
    print(days)
except ValueError:
    print("plz write a value of integer not string")
# Out:
# Enter the age: 43
# 15695
